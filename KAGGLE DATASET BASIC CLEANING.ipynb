# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### IMPORTING THE DATASET

# %%
audible_dataset=pd.read_csv(r'DATASETS\audible_uncleaned.csv')

# %% [markdown]
# ## SUMMARY OF THE DATA
# ### THIS CONTAINS IMPORTANT DATA OF AUDIOBOOKS RELEASED FROM 1998 TO 2025
# IT CONTAINS 87489 ROWS AND 8 COLUMNS

# %% [markdown]
# ## COLUMN DETAILS
# ### It contains 9 columns
# - **NAME**: Name of audiobook
# - **AUTHOR**: Author of the audiobook
# - **NARRATOR**: Narrator of the audiobook
# - **TIME**: Length of the audiobook
# - **RELEASEDATE**: Release date of the audiobook
# - **LANGUAGE**: Language of the audiobook
# - **STARS**: Number of stars the audiobook received
# - **PRICE**: Price of the audiobook in INR
# - **RATINGS**: Number of reviews received by the audiobook

# %% [markdown]
# # Issues Identified During Manual Inspection
#
# ## Dirty Data Issues
#
# 1. Column names are not standardized and need to be corrected.
#
# 2. The `Name` column contains:
#    - Spelling mistakes
#    - Character encoding issues (e.g., `â€™`, `Ã©`, `Ð`, `Ñ`)
#
# 3. Remove the prefix `WrittenBy:` from the `Written By` column.
#
# 4. Author names should be separated into:
#    - First Name
#    - Last Name
#
# 5. The `Written By` column contains encoding issues.
#
# 6. Remove the prefix `NarratedBy:` from the `Narrator` column.
#
# 7. The `Narrator` column contains encoding issues.
#
# 8. Narrator names should be separated into:
#    - First Name
#    - Last Name
#
# 9. The `Time` column should be converted to an appropriate datetime/time format.
#
# 10. Many records contain `Anonymous` as the author. Further investigation is required to determine whether this represents missing information or a legitimate author value.
#
# 11. The `Release Date` column should be converted to datetime format.
#     - Mixed date formats are present:
#       - `DD-MM-YYYY`
#       - `MM-DD-YYYY`
#
# 12. The `Language` column contains inconsistent capitalization:
#     - Uppercase values
#     - Lowercase values
#     - Title Case values
#
# 13. The `Price` column should be converted to a numeric data type also some entries are free which we need to change to 0
#
# 14. The `Rating` column contains some empty values which are represented as 'Not rated yet"
#
# ---
#
# ## Untidy Data Issues
#
# 1. The `Ratings` column contains multiple variables in a single column:
#    - Star Rating
#    - Number of Reviews
#
#    These should be separated into two independent columns:
#
#    - `Stars`
#    - `Number_of_Reviews`

# %%
audible_dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         87489 non-null  str
#  1   author       87489 non-null  str
#  2   narrator     87489 non-null  str
#  3   time         87489 non-null  str
#  4   releasedate  87489 non-null  str
#  5   language     87489 non-null  str
#  6   stars        87489 non-null  str
#  7   price        87489 non-null  str
# dtypes: str(8)
# memory usage: 5.3 MB

# %%
audible_dataset.sample(10)
# Out:
#                                 name  \
# 70226        Volare fino alle stelle
# 57863              Rich Dad Poor Dad
# 70647          Christmas in Bayberry
# 54317            One Day in December
# 66597             Hiding in the Pews
# 33025               Sitting Together
# 25727                  In Cold Blood
# 71279                  Winter Wishes
# 71806               Opnieuw beginnen
# 81214  How Football Explains America
#
#                                                   author  \
# 70226                   Writtenby:SusanElizabethPhillips
# 57863                         Writtenby:RobertT.Kiyosaki
# 70647          Writtenby:JenniferFaye,HallmarkPublishing
# 54317                              Writtenby:JosieSilver
# 66597         Writtenby:SteveAustin,RobertW.Lee-foreword
# 33025  Writtenby:SusanM.PollakEdD,ThomasPedulla,Ronal...
# 25727                             Writtenby:TrumanCapote
# 71279      Writtenby:FernMichaels,SusanFox,JulesBennett,
# 71806                             Writtenby:RobinPilcher
# 81214                           Writtenby:SalPaolantonio
#
#                                        narrator                time  \
# 70226                  Narratedby:TittiSaraceno  12 hrs and 33 mins
# 57863                     Narratedby:TimWheeler    6 hrs and 9 mins
# 70647                    Narratedby:EmilyRankin   8 hrs and 46 mins
# 54317  Narratedby:EleanorTomlinson,CharlieAnson  10 hrs and 27 mins
# 66597                     Narratedby:AdamVerner    7 hrs and 8 mins
# 33025                      Narratedby:PaulBrion   7 hrs and 44 mins
# 25727                     Narratedby:ScottBrick  14 hrs and 27 mins
# 71279                    Narratedby:AmyMcFadden  10 hrs and 51 mins
# 71806                      Narratedby:GwennyVos  11 hrs and 41 mins
# 81214                    Narratedby:PaulBoehmer   7 hrs and 10 mins
#
#       releasedate language                            stars     price
# 70226    18-08-18  italian                    Not rated yet    766.00
# 57863    15-06-12  English  4.5 out of 5 stars5,324 ratings    837.00
# 70647    21-07-20  English                    Not rated yet    820.00
# 54317    23-08-18  English       4 out of 5 stars48 ratings    820.00
# 66597    02-11-21  English                    Not rated yet    586.00
# 33025    08-10-19  English                    Not rated yet    586.00
# 25727    03-01-06  English     4.5 out of 5 stars21 ratings  1,131.00
# 71279    31-10-17  English                    Not rated yet  1,005.00
# 71806    11-02-22    dutch                    Not rated yet    267.00
# 81214    26-03-14  English                    Not rated yet    668.00

# %%
audible_dataset.duplicated().sum()
# Out:
# np.int64(0)

# %%
audible_dataset.describe()
# Out:
#                   name              author              narrator    time  \
# count            87489               87489                 87489   87489
# unique           82767               48374                 29717    2284
# top     The Art of War  Writtenby:矢島雅弘,石橋遊  Narratedby:anonymous  2 mins
# freq                20                 874                  1034     372
#
#        releasedate language          stars   price
# count        87489    87489          87489   87489
# unique        5058       36            665    1011
# top       16-05-18  English  Not rated yet  586.00
# freq           773    61884          72417    5533

# %%
audible_dataset.head()
# Out:
#                                          name                     author  \
# 0                  Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                            The Burning Maze      Writtenby:RickRiordan
# 2                                The Deep End       Writtenby:JeffKinney
# 3                        Daughter of the Deep      Writtenby:RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
#
#                     narrator                time releasedate language  \
# 0      Narratedby:BillLobely   2 hrs and 20 mins    04-08-08  English
# 1   Narratedby:RobbieDaymond   13 hrs and 8 mins    01-05-18  English
# 2      Narratedby:DanRussell    2 hrs and 3 mins    06-11-20  English
# 3  Narratedby:SoneelaNankani  11 hrs and 16 mins    05-10-21  English
# 4  Narratedby:JesseBernstein              10 hrs    13-01-10  English
#
#                            stars   price
# 0     5 out of 5 stars34 ratings  468.00
# 1   4.5 out of 5 stars41 ratings  820.00
# 2   4.5 out of 5 stars38 ratings  410.00
# 3   4.5 out of 5 stars12 ratings  615.00
# 4  4.5 out of 5 stars181 ratings  820.00

# %%
audible_dataset.tail()
# Out:
#                             name                    author  \
# 87484  Last Days of the Bus Club    Writtenby:ChrisStewart
# 87485                   The Alps   Writtenby:StephenO'Shea
# 87486       The Innocents Abroad       Writtenby:MarkTwain
# 87487      A Sentimental Journey  Writtenby:LaurenceSterne
# 87488                     Havana   Writtenby:MarkKurlansky
#
#                       narrator               time releasedate language  \
# 87484  Narratedby:ChrisStewart  7 hrs and 34 mins    09-03-17  English
# 87485    Narratedby:RobertFass  10 hrs and 7 mins    21-02-17  English
# 87486     Narratedby:FloGibson  19 hrs and 4 mins    30-12-16  English
# 87487   Narratedby:AntonLesser   4 hrs and 8 mins    23-02-11  English
# 87488   Narratedby:FleetCooper    6 hrs and 1 min    07-03-17  English
#
#                stars   price
# 87484  Not rated yet  596.00
# 87485  Not rated yet  820.00
# 87486  Not rated yet  938.00
# 87487  Not rated yet  680.00
# 87488  Not rated yet  569.00

# %%
audible_dataset['name'].tolist()
# Out:
# ['Geronimo Stilton #11 & #12',
#  'The Burning Maze',
#  'The Deep End',
#  'Daughter of the Deep',
#  'The Lightning Thief: Percy Jackson, Book 1',
#  'The Hunger Games: Special Edition',
#  'Quest for the Diamond Sword',
#  'The Dark Prophecy',
#  'Merlin Mission Collection',
#  'The Tyrant’s Tomb',
#  "The Titan's Curse: Percy Jackson, Book 3",
#  'Magic Tree House Collection: Books 9-16',
#  'Magic Tree House Collection: Books 1-8',
#  'Magnus Chase and the Ship of the Dead',
#  'Northern Lights',
#  'Geronimo Stilton #13 and #14',
#  'Magic Tree House Collection',
#  'Exile',
#  'Merlin Mission Collection',
#  'Neverseen',
#  'The Tower of Nero',
#  'Eldest: The Inheritance Cycle, Book 2',
#  'Artemis Fowl',
#  'Geronimo Stilton 22 & 24',
#  'Percy Jackson and the Battle of the Labyrinth',
#  'Winnie-the-Pooh',
#  'Magic Tree House Collection: Books 25-32',
#  'Geronimo Stilton #20 and #21',
#  'The Red Pyramid',
#  "Mystery of the Griefer's Mark",
#  'Geronimo Stilton #17',
#  'The House at Pooh Corner',
#  'Mission Unstoppable',
#  'Darkness of Dragons',
#  '14 Short Stories Bundle for Kids: Adventure, Science Fiction, Aesop’s Fables, Classic Fairy Tales and Christmas Story Books for Children',
#  'The Adventures of Rusty',
#  'Geronimo Stilton #15 and #16',
#  'The Lost Heir',
#  'Everblaze',
#  'Treasure Hunters in Trouble',
#  'Lodestar',
#  'Curse of the Arctic Star',
#  'The Ghost of Grey Fox Inn',
#  "Rowley Jefferson's Awesome Friendly Adventure",
#  'Flashback',
#  'Secret of the Red Arrow',
#  'The Lightning Thief: Percy Jackson, Book 1',
#  'Clash of the Creepers',
#  'The Skeletons Strike Back',
#  'Dragonslayer',
#  'A Bear Called Paddington',
#  'Gregor and the Curse of the Warmbloods',
#  'The Dark Secret',
#  "The Gruffalo's Child",
#  'Merlin Mission Collection',
#  'Keys to the Demon Prison',
#  'Legacy',
#  'The Endermen Invasion',
#  'Captain Underpants and the Revolting Revenge of the Radioactive Robo-Boxers',
#  'You Only Die Twice',
#  'From Texas with Love',
#  'Across the Desert',
#  'Unicorn Academy: Aisha and Silver',
#  'Laura Blackman and The Five Cunning Aardvarks',
#  'The Dragonet Prophecy',
#  'Dangerous Gift',
#  'The 39 Clues, Book 6',
#  'Never Say Genius',
#  'The Madman of Black Bear Mountain',
#  'Unicorn Academy: Zara and Moonbeam',
#  'El fantasma de la bodega',
#  'El paseo encantado',
#  'Wigetta',
#  'Aru Shah and the Nectar of Immortality',
#  'Barnabas der Wolkenschaufler',
#  'The Boy in the Post',
#  'Thornwood',
#  "7 histoires d'aventures !",
#  'Le Loup qui devenait chef de la forêt',
#  'Curse of the Robo-Dragon',
#  'Call of the Crow',
#  'Glass Slippers',
#  'Captain Underpants and the Sensational Saga of Sir Stinks-a-Lot',
#  'Tiger Honor',
#  'The Amulet of Samarkand',
#  "Rowley Jefferson's Awesome Friendly Spooky Stories",
#  'Lost in the End',
#  'Trouble Island',
#  'Terrors of the Forest',
#  'Riverboat Roulette',
#  'The Book of Chaos',
#  'Fortunately, the Milk...',
#  'Discoveries in the Overworld',
#  'The Last Human',
#  'Welcome to Smellville',
#  "An Explorer's Guide to the Nether",
#  'The Midnight Gang',
#  'As the Falcon Flies',
#  'The Squad of Lucky Landing: An Unofficial Fortnite Adventure Novel',
#  'Pahua and the Soul Stealer',
#  'El monstruo marino secreto',
#  'Sabotage on the Solar Express',
#  'A Boy Called Christmas',
#  'The 39 Clues, Book 4',
#  'The 39 Clues, Book 3',
#  'The Disappearance',
#  'Once Upon a Crime',
#  'Billionaire Boy',
#  'The Blue Lady of Coffin Hall',
#  "Danger at Dead Man's Pass",
#  'Unlocked',
#  'The Danger Gang',
#  'Mountain Mare',
#  'The Princess in Black and the Mermaid Princess',
#  'The Vanishing Statue',
#  'Eye of the Earthquake Dragon',
#  'Peril at Granite Peak',
#  'Barbie - Aventura espacial',
#  'The Disappearance of Emily Downs',
#  'The Solution',
#  'The Great Greenfield Bake-Off',
#  'Into Thin Air',
#  'Once upon a Thriller',
#  "The Magician's Nephew",
#  'Leonora Bolt: Secret Inventor',
#  'The Snail and the Whale',
#  'Tigers for Dinner',
#  'The Hidden Kingdom',
#  'Eagle Strike',
#  'Captain Marvel - Ultron blir viral',
#  'Toy Story 4',
#  'Three Lost Seeds',
#  'Mystery on the Mayhem Express',
#  'Tunnel of Secrets',
#  'Barbie - La puerta secreta',
#  'A scuola con Pongo e Tim: Henry Every',
#  'Black Panther: Spellbound',
#  'The 39 Clues: Unstoppable, Book 3',
#  'Hello Kitty - El Club de la Amistad',
#  'Treasure Island',
#  'The Human Body',
#  'Minecraft: The Dragon',
#  'The Christmasaurus and the Naughty List',
#  'Das Exil',
#  'El Cerdito de Navidad [The Christmas Pig]',
#  'Big Change for Stuart',
#  'The Imagination Box: Beyond Infinity',
#  'Camp Daze',
#  'Vaiana',
#  'Myth of the Rain Forest Monster',
#  'Little Badman and the Time-travelling Teacher of Doom',
#  'The Great Dream Robbery',
#  'Barbie - Superprincesa',
#  'Barbie - El campamento de princesas',
#  'Barbie - Dreamtopia',
#  'Barbie - Superprincesa',
#  'Among Us Book - Red Diary',
#  'We’re Going to Find the Monster',
#  'Ut i det vilda',
#  'The Imagination Box: A Mind of Its Own',
#  "Dungeons & Dragons: The Mad Mage's Academy",
#  'Scary Stories for Young Foxes: The City',
#  'Med kunglig stämpel',
#  'Bolt',
#  'The Tenth Son',
#  'Escape from Falaise',
#  'The Jungle Book',
#  'PJ Masks - 3-Minuten-Gutenachtgeschichten',
#  'Opapi-Opapa - Volle Kraft voraus!',
#  'Opapi-Opapa - Besuch von den Krawaffels',
#  'Als Papa auf einen Knopf drückte und wir fast von einem Dino gefressen wurden',
#  'Spidey og hans fantastiske venner',
#  'Phantom Stallion: Blue Wings',
#  'Super Pigiamini - Storie della buonanotte da 5 minuti',
#  'Lost Island',
#  'The Boy Who Hatched Monsters',
#  'The Magic Ocean Slide & The Giant Conker',
#  'Krieg der Fluten',
#  'The Secret of Splint Hall',
#  'Tschakka! - Freunde in Sicht',
#  'El candidato novato',
#  'The Call of the Silver Wibbler',
#  'Frankie Best Hates Quests',
#  'Trapped in the Overworld',
#  'The Boy Who Biked the World: On the Road to Africa',
#  'The 143-Storey Treehouse',
#  'Unicorn Academy: Isla and Buttercup',
#  "Herobrine's War",
#  'Small Change for Stuart',
#  'The Extreme',
#  "Alain l'alien",
#  'Wingfeather Tales',
#  'Spider-Man gegen Sandman / Spider-Man und die Marvels',
#  'Swamp Sting!',
#  'Poison Jungle',
#  '39 Clues: Cahills vs. Vespers',
#  'Adventure Time - Too Many Bananas & Other Stories',
#  'Blue Moon',
#  "The Last Kids on Earth: June's Wild Flight",
#  'Captain Underpants and the Terrifying Return of Tippy Tinkletrousers',
#  'Mermaids of the Deep Blue Sea',
#  'Flying Ninja!',
#  'Fortress of the Stone Dragon',
#  'Zoey and Sassafras: The Pod and the Bog',
#  'PJ Masks - Héroes en Pijamas - ¡Los lobeznos!',
#  'PJ Masks - Potència PJ!',
#  'PJ Masks - Preparats per a l’acció!',
#  'Mortel un jour, Mortel toujours!',
#  'Pyjamasankarit - 3 minuutin iltasatuja',
#  'PJ Masks - Vet aquí en Robot PJ!',
#  'PJ Masks - PJ Robot',
#  'Le géant de pierre',
#  'Pyjamasankarit - Nousu taikavuorelle',
#  'PJ Masks - Héroes en Pijamas - Catboy y el gran rescate de la torta de cumpleaños',
#  'Tijl en de tijdbom',
#  'Genius Camp',
#  'The Talisman of Lostland',
#  'Star Wars: The High Republic: A Test of Courage',
#  'The Secret Explorers and the Plant Poachers',
#  'The Red Slippers',
#  'Captain Underpants and the Preposterous Plight of the Purple Potty People',
#  "The Magician's Secret",
#  'The Case of the Bizarre Bouquets',
#  'Shockwave',
#  'The Phantom of Nantucket',
#  'The Swamp Robber',
#  'The Magic Finger',
#  'The Adventures of Captain Underpants',
#  'Secret at Mystic Lake',
#  'Fight for Dusty Divot',
#  'I Survived the Sinking of the Titanic, 1912',
#  'Showdown at Widow Creek',
#  'Case of the Missing Marquess',
#  'Nightshade',
#  'Mystery of the Phantom Heist',
#  "Mousse à l'école des pirates",
#  'Riding Home Through Asia',
#  'The Boy Who Biked the World: Riding the Americas',
#  'El Misterio de la Montaña Azul',
#  'Grand-mère Sucre et Grand-père Chocolat',
#  'La chambre des pirates',
#  'Tapator le dinosaure',
#  'Une pomme pour deux',
#  'Roméo et Biquette',
#  'Bienvenue chez Vampirette',
#  'Toc, toc ! Qui est là ?',
#  'Un poisson nommé Marina',
#  'Du lait pour mon chat',
#  'Le grand voyage de Nils Holgersson',
#  'Qui veut jouer avec Renard ?',
#  'Le petit roi Moi Moi Moi !',
#  'Pas de lunettes sur ma tête !',
#  'Penny Berry y la batalla de Cairngorms',
#  'Marvel - Tillbaka till urtiden',
#  'Thor - Begynnelsen - Fin Fang Fooms uppgång och fall!',
#  'Black Panther - Kampen om Wakanda',
#  'Ali Baba and the Forty Thieves',
#  'La fée Fifolette a cassé sa baguette',
#  "Le gros chagrin d'Edgar",
#  'Qui a volé le diamant de Big Jack ?',
#  'La fée Fifolette déclenche des tempêtes',
#  'Le petit chevalier courageux',
#  'La banda della zuppa di piselli',
#  'Princesse Sarah',
#  "Le voleur d'Edith",
#  'Veinte mil leguas de viaje submarino',
#  'Historias de miedo',
#  'Misterio en las vías',
#  'Sofabanditen oder Die verrückte Befreiung der Hühner',
#  'En el infierno',
#  'PJ Masks: Carrera en la Montaña Misteriosa',
#  'DC Jones and Adventure Command International 2',
#  'Robatori a la platja',
#  'Barbie - Dreamtopia',
#  'Barbie - Els superpoders de princesa',
#  'Barbie - Pop per a princeses',
#  'Limamerirosvojen jäljillä',
#  'Barbie - Buscant les gossetes',
#  'Barbie - La porta secreta',
#  'Die Hamsterdam-Verschwörung',
#  'Els Barrufets - Històries dels barrufets',
#  'La maison qui ne dormait jamais',
#  'Els Barrufets - Històries de 3 minuts',
#  'Wolvenhart',
#  'Circus Maximus Rivals on the Track',
#  'PJ Masks - Cursa cap a la Muntanya Misteriosa',
#  "Super Pigiamini - Pronti all'azione!",
#  'PJ Masks - En Gatnoi i el gran rescat del pastís d’aniversari',
#  'Anatole Latuile fait son cinéma',
#  'The Midnight Thief',
#  'Suche nach der verborgenen Quelle',
#  'El misterio del coleccionista de tazos',
#  'Los Pitufos - Historias de Pitufos',
#  'Dando la nota',
#  'Los Pitufos - Historias de 3 minutos',
#  'Vacaciones, no gracias',
#  "A Baker's Guide to Robber Pie",
#  'The Counterclockwise Heart',
#  'Knight Sir Louis and the Dragon of Doooooom!',
#  'Ferien auf Saltkrokan - Pelle findet einen Wunschstein',
#  'Bob el Constructor - Perros y gatos',
#  'The Secret of Haven Point',
#  'The Mouse Watch in Space',
#  'Freewater',
#  'The Book of Stolen Time',
#  'The Experiment',
#  'The Exposed',
#  'Big Sky Mountain: The Forest Wolves',
#  "The Golem's Eye",
#  'The Count of Monte Cristo',
#  'Howl of the Wind Dragon',
#  'Pony',
#  'World Champions!',
#  'Minecraft: Mob Squad',
#  'The Threat',
#  "The Tiger's Nest",
#  'The Beekeeper Mystery',
#  'The Shattered Castle',
#  'Peanut Jones and the Illustrated City: from the creator of Draw with Rob',
#  'Sparrow Rising',
#  'Shadowghast',
#  'The Beatryce Prophecy',
#  'Brother Wulf',
#  'Rise of the World Eater',
#  'The Unadoptables',
#  "Barbie - Equip d'espies",
#  'The Mapmakers',
#  'The Professor and the Puzzle',
#  'The Paper Dolls',
#  'The 39 Clues, Book 5',
#  'Scorpia',
#  'A Con Artist in Paris',
#  'Tunnel of Bones',
#  'The 13-Storey Treehouse',
#  'The 39 Clues, Book 9',
#  'Kid Normal and the Rogue Heroes',
#  'Shine of the Silver Dragon',
#  'Treasure of the Gold Dragon',
#  'The Jungle Book',
#  'The 1,000-Year-Old Boy',
#  'Strangers on a Train',
#  'Darkstalker',
#  'Peter Rabbit 2',
#  'Dinosaurs Before Dark',
#  'The Outcast',
#  'Wave of the Sea Dragon',
#  'Escape from Aurora',
#  'The Monkey King',
#  'Getting Granny’s Glasses',
#  'Where the Red Fern Grows',
#  'The 39 Clues, Book 10',
#  'Future of the Time Dragon',
#  'Field Trip Fiasco',
#  'Captain Underpants and the Big, Bad Battle of the Bionic Booger Boy, Part 2',
#  'The Carpet People',
#  'Clash at Fatal Fields',
#  'Deception on the Set',
#  'The Tale of Tom Kitten',
#  '20.000 Leguas de viaje submarino [20,000 Leagues Under the Sea]',
#  'Dungeons & Detectives',
#  'A Script for Danger',
#  'The Battle of Bayport',
#  'Capitaine',
#  'Iron Man - Rymdfantomernas invasion!',
#  'City of Ghosts - Im Reich der vergessenen Geister',
#  'Ariana y Arcana',
#  'La aventura de Amunet',
#  'Amigos de verdad',
#  'Pan, nuestro hermano del bosque',
#  'PJ Masks - Vet aquí els Mini Llops!',
#  'Ufo in Seenot',
#  'The Chromatics Camp at The Musical Mountain',
#  'Attack of the Shadow-Crafters',
#  'Не буду просить прощения',
#  'Ritter Klapperschwert und die große Freundschaft',
#  'H@Ck - Het instituut',
#  'Маленький лорд Фаунтлерой',
#  'Głupi Funio',
#  'Un problema con alas',
#  'Die Meckerpause',
#  'El Club de la Luna Llena',
#  'Spider-Man - En samling berättelser',
#  'Enigma en el puente del naranjo',
#  'Penny Berry y la cripta de los olvidados',
#  'Penny Berry y la pócima mágica',
#  'La casa embrujada',
#  'Lady och Lufsen',
#  'Тишина на задней парте!',
#  'James und die fischige Fracht / Hiro und die widerspenstigen Waggons',
#  'Avengers - God Jul!',
#  'En busca del señor T',
#  'Avengers - TRE spektakulära äventyr!',
#  'Captain America och morgondagens armé!',
#  'Superhjältarna',
#  'Лесные истории',
#  'Spider-Man - Kortslutning',
#  'Перчатки Ариадны',
#  'The Far-Finding Ring',
#  'When the War Came Home',
#  'Modig - Meridas önskan',
#  'Il viaggio leggendario di Erick e Dominick',
#  'Doctor Strange - Vejen til viden',
#  'Pyjamasheltene - Kattedreng og den store fødselsdagskageredning',
#  'Pyjamasheltene redder dagen!',
#  'The Great Zombie Invasion',
#  'The Buried Crown',
#  'The Wishing Star & The North Pole Picnic',
#  'Cora y los Corales',
#  'Fortidens skygger',
#  "Racconti dall'India",
#  'Piratbarn har ikke længere brug for sin sut',
#  'Alpaca My Bags',
#  "L'île du mage",
#  'Speedy',
#  'The Santa List',
#  'Paradise Pirates retten Captain Scratch',
#  'Loca por Hugo',
#  'Ninja Niller - Blodets Bånd: Del 4',
#  'Marvel - Den stora sagosamlingen',
#  'Bilar 3',
#  'Falcon - Fäkta eller flyga',
#  'Barbie - Aventura en el espacio',
#  'El misterio de la virgulina inmortal',
#  'Ein Mädchen namens Owl',
#  'Antigua de Fortune of the High Seas',
#  'The Smidgens',
#  "Revolució a la botiga d'animals",
#  'Te regalo el mundo',
#  'Et regalo el món',
#  'Revolución en la tienda de animales',
#  'Ribblestrop Forever!',
#  'Это грузовик, а это прицеп',
#  'Страна Хороших Девочек',
#  'Записки институтки',
#  'Синичкин календарь',
#  'Новые правила поведения для воспитанных детей',
#  'Поллианна',
#  'Психология окружающего мира. Дуня и кот Кисель на конюшне',
#  'Тринадцатый подвиг Геракла. Рассказы о Чике (Сборник)',
#  'Единорог для круглой принцессы',
#  'Четыре желания',
#  'Нектар для души. Вдохновляющие истории для детей 7-10 лет',
#  'Ага, попался!',
#  'Васюткино озеро. Рассказы для детей',
#  'Das Feuer',
#  'Familie Maulwurf auf der Flucht',
#  'Die Spiegelspringer - Im Bann der Geschichten',
#  'The Attack',
#  'Symbiosis',
#  'Stella und der Mondscheinvogel',
#  'Saids Schicksale',
#  'Surviving Jamestown',
#  '¡Sálvese quien pueda!',
#  'Cuentos locos para niños inteligentes',
#  'Wednesday: The Forest of Secrets',
#  'Ronan Boyle into the Strangeplace',
#  'Girl Giant and the Jade War',
#  'Kidnapped Colt',
#  'Cómo como',
#  'Der Zeitring',
#  'Ivy & Bean Bound to Be Bad (Book 5)',
#  'Ivy & Bean Take Care of the Babysitter (Book 4)',
#  'Ivy & Bean Break the Fossil Record (Book 3)',
#  'Moonrise',
#  'Vega Jane and the End of Time',
#  'The Suspicion',
#  'The Pretender',
#  'Hide and Geek',
#  'Sunlight on the Snow Leopard',
#  'Me and My Little Brain',
#  'Coraline',
#  'The Van Gogh Deception',
#  'Moon Rising',
#  'Abenteuer-Ferien bei Opa Balduin',
#  'Hello Kitty - La aventura animal',
#  'Hello Kitty - La estrella de televisión',
#  'Hello Kitty - Vacaciones en la playa',
#  'Hello Kitty - El misterio de la madalena',
#  'Hello Kitty - La búsqueda del tesoro',
#  'Hello Kitty - Sesión de belleza',
#  'Ravenburcht',
#  'De Utrolige 2',
#  'Ariadna y la luna Lunera',
#  "L'Ariadna i la lluna Pruna",
#  'La Mariona i la Menjanits',
#  'Captain Underpants and the Attack of the Talking Toilets',
#  'Holes',
#  'The 39 Clues, Book 1',
#  'The Princess in Black, Books 1-3',
#  'Pyjamasankarit - Tässä tulee Pyjamarobotti!',
#  'Pyjamasankarit - Polkuvoimaa!',
#  'PJ Masks - Sigues un heroi!',
#  'Pyjamasankarit - Ollaan sankareita',
#  'Pyjamasankarit - Tässä tulee susijengi',
#  'Pyjamasankarit - Kolli ja synttärikakun pelastusoperaatio',
#  'Fly High Crew: The Green Glow',
#  'Vitello va a un cumpleaños de niñas',
#  'Vitello compra un maravilloso regalo de Navidad',
#  'Vitello salva el mundo',
#  'Vitello construye un Abominable Hombre de las Nieves',
#  'Vitello hace una obra de caridad',
#  'Vitello pide un deseo',
#  'Vitello pide un montón de chuches',
#  'Barbie - En busca de las cachorritas',
#  'El misterio del ladrón narizotas',
#  'Willy y el arenque asesino',
#  'Pasado por auga',
#  'PJ Masks - ¡Los niños lobunos!',
#  'Noémie Hollemechette',
#  'Los Pitufos - Historias de Pitufos',
#  'Los Pitufos - Historias de 3 minutos',
#  'Il primo disastroso libro di Matt',
#  'Françoise la mauvaise tête',
#  'Sotto la stella del lupo',
#  'Los Rescatadores Mágicos y la tostadora de los deseos',
#  'Superhjältar på äventyr - Spider-Man får superhjälp!',
#  'Atrapados en el monte Olimpo',
#  'The Worst Class in the World Dares You!',
#  'Der Ruf des Mondsteins',
#  'Pizza Power',
#  "The Case of the Smuggler's Curse",
#  'The Lock-Eater',
#  'Brave New Pond',
#  'The Box-Car Children',
#  'Wild River',
#  'The Wild Robot: Booktrack Edition',
#  'Skeleton Key',
#  'Demon Dentist',
#  'Hidden Pictures',
#  'The Lost Continent',
#  'Unicorn Academy: Ariana and Whisper',
#  'A Long Walk to Water',
#  'Talons of Power',
#  'Bound for Danger',
#  'Captain Underpants and the Big, Bad Battle of the Bionic Booger Boy, Part 1: The Night of the Nasty Nostril Nuggets',
#  'Hello Kitty - El día de la boda',
#  'Hello Kitty - La excursión escolar',
#  'Hello Kitty - La princesa del pop',
#  'Het\xa0oneindige\xa0verhaal',
#  'Mariona y Comenoches',
#  'Thomas@geraamte.net (Afrikaans Edition)',
#  'Чучело',
#  'Маленькая принцесса',
#  'Маленький принц',
#  'Warhammer Adventures: Battle for the Soulspring',
#  'Warhammer Adventures: Fortress of Ghosts',
#  'Black Powder',
#  'Le Mystère du train de la nuit',
#  'Drachenalarm',
#  'Superjuffie!',
#  'Begyndelsen - Storm i sigte',
#  '101 Dalmatinere - Begyndelsen - Anitas hemmelige hvalp',
#  'Złote rękawice Arachne!',
#  'Die Traumwelt',
#  'Swashbuckler',
#  'Paddington, le roman du film',
#  'Get a Hold of Your Elf!',
#  'Niemals den roten Knopf drücken oder die Dinos drehen durch',
#  'Le fabuloup gâteau de Gros-Louis',
#  "Loup et ses amis. L'intégrale",
#  "L'anniversaire de Louve",
#  "Edmond le dragon et l'incendie",
#  'La machine à vœux de Valentin',
#  'La drôle de maladie de Demoiselle Yéti',
#  'Le secret de Joshua',
#  'Alfred et le monstre de la forêt',
#  'Comenoches',
#  'Mörtel und Maus wollen hoch hinaus',
#  'Un viaje más allá de Sodor',
#  'El prisionero de la fantasía',
#  'Das Hotel der Wünsche',
#  'Der Verrat',
#  'Das verbotene Turnier',
#  'Дениска на Севером полюсе [Deniska at the North Pole]',
#  'Lampie',
#  'Spider-Man rettet Weihnachten / Spider-Man und seine Insektenfreunde',
#  'Otto der Flaschengeist',
#  'Peter Pan',
#  "L'Ogre qui aimait les champignons",
#  'Une mission parfumée\xa0!',
#  'De précieux passagers',
#  'La Grande Course',
#  'Un concert enflammé',
#  'Thursdays with the Crown',
#  'Marvel Spider-Man - 5-Min-Geschichten',
#  'Un super match de football',
#  'Un super chien de sauvetage',
#  'The Spitfang Lizard',
#  'Little Horror',
#  'Un sauvetage magique',
#  'Un cheval à sauver',
#  'Canoë à la Dérive\xa0!',
#  'Disparition au Zoo\xa0!',
#  'Concours en péril',
#  'La Tempête de Dhîves',
#  'Im Bannkreis des Schwurs Teil 2',
#  'Im Bannkreis des Schwurs Teil 1',
#  'La Route du courage',
#  'Bazar chez les locomotives',
#  'Le Mystère de la montagne bleue',
#  'Le Roi du chemin de fer',
#  'Que le meilleur gagne !',
#  'Los Atrevidos',
#  'Lucía y Ema dan un paseo en bicicleta',
#  'Lucía y Ema celebran sus cumpleaños',
#  'Lucía recibe un cachorro de regalo',
#  'Gulliver XXI',
#  'Midnatt',
#  'Den mörka floden',
#  'Visionen',
#  'Blood Captain',
#  'Zeinumb. Parque de atracciones',
#  'El mejor regalo del mundo',
#  'The Hunt for the Five',
#  'Un amico a sorpresa',
#  'Eine dunkle Verschwörung',
#  'Alarm im Park',
#  'Los vestidos de Pancheta',
#  'Aventures sur le continent',
#  'Tafiti und der große Zauberer',
#  'Silas and the Marvellous Misfits',
#  'Cheeky and Charlemagne',
#  'El Agujero Negro [The Black Hole]',
#  'La Légende du trésor perdu de Chicalor',
#  'Los rescatadores mágicos en las magiolimpiadas',
#  'Los rescatadores mágicos en el bosque de los gamusinos',
#  'El ladrón de la fantasía',
#  'Freddy vs. School',
#  'City of Rust',
#  'Polly Pecorino',
#  'Mambrú Perdió la Guerra [Mambrú Lost the War]',
#  'Dragon Skin',
#  'Eld och is',
#  'Crowfall',
#  'Die Muskeltiere und die große Käseverschwörung',
#  'Tom und die Schildkrötenschmuggler',
#  'Travesuritis aguda [Acute Travesuritis]',
#  'Hola, ¿puedo ayudar?',
#  'El hombre que perdió su imagen',
#  'Todo se rompe',
#  'The Ice Whisperers',
#  'Malicia en el país de las fechorías',
#  'Wilma Walnuss und das kleine Baumhotel',
#  "Brother Wulf: Wulf's Bane",
#  'The Goldsmith and the Master Thief',
#  'Bin Boy',
#  'Un día en casa',
#  'El guerrero fantasma',
#  'La leyenda del wendigo',
#  'The Raven Heir',
#  'Extra Weird Creatures',
#  'I Survived the Galveston Hurricane, 1900',
#  "The Week at World's End",
#  'The Imagination Box',
#  'Nehmt euch in Acht!',
#  "Allez, les verts! [Let's Go Green!]",
#  'The Monsters of Rookhaven',
#  'Les Histoires pour petites oreilles',
#  'DJ Funkyfoot: Give Cheese a Chance!',
#  'Les aventures de Sven le terrible. Pas de princesse pour les pirates. [The Adventures of Sven the Terrible. No Princess for Pirates.]',
#  'Dungeons & Dragons: Big Trouble',
#  'Dungeons & Dragons: Escape from Castle Ravenloft',
#  'Dungeons & Dragons: Escape the Underdark',
#  'Dungeons & Dragons: To Catch a Thief',
#  'Uno skate per due',
#  'PIN-0-TXO vol tenir amics',
#  'PIN-0-TXO vol tenir ànima',
#  'Noticias frescas',
#  'Una boda desmadrada',
#  'Zack Galaxy: misión secreta',
#  'El rockero',
#  'Un poco de pasta, basta',
#  'Los mayores están locos, locos, locos',
#  'Hijos de Asgard',
#  'La estrellita de mar',
#  'Brisca',
#  'La niña que siempre decía no',
#  'El niño que era muy hombre',
#  'El niño que tenía mucho hermano',
#  'Sólo soy una niña',
#  'El brujo No',
#  'El perro del señor Gris Marengo',
#  'Zorro blanco',
#  'Im kleinen wilden Schnergenland',
#  'Komm flieg mit uns ins Abenteuer!',
#  'Spuren im Wald',
#  'Ein rätselhafter Unfall',
#  'Rupert präsentiert - Ein echt wildes Abenteuer',
#  'Luftpiraten',
#  'Luis und Lena - Der Zwerg des Zorns',
#  'Ozean in Flammen',
#  'Rille - Ein Dschungel voller Abenteuer!',
#  "Émo-J : Attention à l'agent Paul [Emo-J: Watch Out for Agent Paul]",
#  'Dungeons & Dragons: Into the Jungle',
#  'Egg Marks the Spot',
#  'Tabitha Plimtock and the Edge of the World',
#  'Always',
#  'The Puffin Portal',
#  'The Grunts on the Run',
#  'Utterly Dark and the Face of the Deep',
#  'The Peculiar Tale of the Tentacle Boy',
#  'A Mouse Called Miika',
#  'Nell and the Cave Bear',
#  'Oupa Zombie',
#  'The Other Side of Luck',
#  'Heartbreak Bronco',
#  'Rain Dance',
#  'Untamed',
#  'Red Feather Filly',
#  'Gift Horse',
#  "Vega Jane and the Rebels' Revolt",
#  'The Boy with Wings',
#  'Tuesday: The Curse of the Blue Spots',
#  'Monday: Into the Cave of Thieves',
#  'City of Thieves',
#  'Concealed',
#  "Ricky Ricotta's Mighty Robot vs. the Naughty Nightcrawlers from Neptune",
#  'A Trick of Time',
#  'Oddity',
#  'Gladys the Magic Chicken',
#  'Me vs. the Multiverse: Enough About Me',
#  'Share Your Rainbow',
#  'The Worries: Jaz and the New Baby',
#  'The Aeneid',
#  'Nuclear Distraction',
#  'Beauty and the Dreaded Sea Beast',
#  'Double Trouble',
#  'La fée Fifolette et le gâteau Bonbon',
#  'Joyeux anniversaire, Princesse Mélie',
#  'Il faut sauver la princesse Blanche !',
#  "Le cadeau d'Amazonie",
#  'Thomas y sus amigos - Misterio en las vías',
#  'Bob y sus amigos - Perros y gatos',
#  'Thomas y sus amigos - La gran carrera',
#  'Thomas y sus amigos - El rey de las vías',
#  'Thomas y sus amigos - El Misterio de la Montaña Azul',
#  'El monstruo marino secreto',
#  'Thomas y sus amigos - Historias de miedo',
#  'Bob y sus amigos - La casa del árbol de Saffi',
#  'Thomas y sus amigos - Carrera hacia el castillo de Callan',
#  'Thomas y sus amigos - Día de los Diésel',
#  'Bob y sus amigos - El dinoparque',
#  'Qui a volé le deuxième but? [Who Stole Second Base?]',
#  'Thomas@sms.net (Afrikaans Edition)',
#  'Thomas@rock-ster.net (Afrikaans Edition)',
#  'Thomas@skaduwee.net (Afrikaans Edition)',
#  'Penny Berry y el árbol de oro de Shangri-La',
#  'Le très chanceux monsieur Confetti',
#  "C'est la petite bête qui monte",
#  'Li Le La',
#  'Superhjältarna 2',
#  'Bamse ja noita-akan tytär',
#  'Escape Room',
#  "Les mémoires d'un âne de la Comtesse de Ségur",
#  'Les deux nigauds de la Comtesse de Ségur',
#  'Phantom Stallion: Secret Star',
#  'Thomas y sus amigos - El rey de las vías',
#  'Petit-Gaulois veut des moustaches',
#  'Les vacances de la Comtesse de Ségur',
#  'Les petites filles modèles de la Comtesse de Ségur',
#  'Thor - Helten fra Asgård',
#  '1er zavril sur la planète Zars',
#  'Les malheurs de Sophie de la Comtesse de Ségur',
#  "L'auberge de l'Ange-gardien de la Comtesse de Ségur",
#  'Le général Dourakine de la Comtesse de Ségur',
#  'Un bon petit diable de la Comtesse de Ségur',
#  "La Montagne d'ébène [The Ebony Mountain]",
#  'Thomas@vrees.net (Afrikaans Edition)',
#  'Thomas y sus amigos - ¡Que gane el mejor!',
#  'Spider-Man og Iron Man - Mød dine helte!',
#  'The Balloon Thief',
#  'Getting to the Bottom of Global Warming',
#  'Les 12 Coffrets de Goradenn le Fol',
#  'Gschichte vom Schnüff',
#  'Penny Berry y el anillo de Shazzan',
#  'Bamse ja maailman seitsemän uutta ihmettä',
#  'Vi Spy 2',
#  'PJ Masks - Catboy bjargar afmæliskökunni',
#  'PJ Masks - Gatuno y la encogedora',
#  'PJ Masks: Héroes en Pijamas - ¡Allá vamos!',
#  'PJ Masks: Héroes en Pijamas - Catboy y la máquina encogedora',
#  'PJ Masks: Héroes en Pijamas - Robot en pijama',
#  'PJ Masks: Héroes en Pijamas - Cuentos de tres minutos para dormir',
#  'PJ Masks: Héroes en Pijamas - ¡Héroes y heroínas!',
#  'PJ Masks - Carrera en la Montaña Misteriosa',
#  'PJ Masks: Héroes en Pijamas - ¡Pedaleando a toda velocidad!',
#  'PJ Masks - Cuentos para dormir de tres minutos',
#  'PJ Masks - Contes de 3 minuts per anar a dormir',
#  'PJ Masks - En Gatnoi i l’Encongidor',
#  'Pidżamersi - Bądź bohaterem!',
#  'Mauritz findet das Glück',
#  'PIN-8 quiere tener superfuerza',
#  'Tafiti und die Expedition zum Halbmondsee',
#  'Le vaillant petit tailleur',
#  'Les chevaliers',
#  'Maya et le volcan Pipicaca',
#  'Merci pour les crêpes, Jasmin !',
#  'Una tormenta de deseos',
#  "7 histoires d'enquêtes !",
#  'Le cakosaure de Nino Dino',
#  'Le doudou du loup',
#  'Les pompiers',
#  'Los Bandídez',
#  "Fiabe d'incantesimi",
#  'Susanna e il soldato',
#  'Le manchot qui voulait avoir chaud',
#  'Le petit pompier',
#  "Zouk à l'école des sorciers",
#  'Der Wildtöter',
#  'Graffiti & Cie',
#  'Carrera hacia el castillo de Callan',
#  'La gran carrera',
#  'Le petit empereur de Chine',
#  'La ermita de los espíritus',
#  'A Thunder of Monsters',
#  'Fabula - Das Portal der dreizehn Reiche',
#  'Racing Storm Mountain',
#  'Día de los Diésel',
#  'La leyenda del tesoro perdido',
#  'Grimorgas Erwachen',
#  'Der wahrlich wildbewegte Flug im Luftschiff',
#  'El ladrón de salchichón',
#  'Barbie - Equipo de espías',
#  'Misterio en el campo de golf',
#  'Sea Monsters - Ungeheuer weckt man nicht',
#  'Barbie - La puerta secreta',
#  'El misterio de los ocho bebés',
#  'Un viaje más allá de Sodor',
#  '¡Que gane el mejor!',
#  'Juan y el teatro de la lluvia',
#  'Barbie - Aventura en el espacio',
#  'PJ Masks - ¡Pedaleando a tope!',
#  'PJ Masks - Gatuno y el gran rescate de la tarta de cumpleaños',
#  'Aufbruch ins Land der Tierflüsterer',
#  'Caspar und die Träne des Phönix',
#  'Minna Melone - Wundersame Geschichten aus dem Wahrlichwald',
#  'Atemlos',
#  'El misterio de la gata maga',
#  'Ein gefährlicher Pakt',
#  'The House in the Woods',
#  'The Ghost of Scarletbeard',
#  'Mort the Meek and the Monstrous Quest',
#  'Ambrose Follows His Nose',
#  'The Reunion',
#  'Noni and the Great Chawwwklit Mystery',
#  'Adventures in Super Happy Magic Forest',
#  'The Secret Explorers and the Moon Mission',
#  'The Last Firefox',
#  'The Sickness',
#  'Thursday: War of the Waterslides',
#  "The Gas-Fitters' Ball",
#  "Thunderbolt's Waxwork",
#  'Children of the Flying City',
#  'A to Z Mysteries Super Edition 10: Colossal Fossil',
#  'Minecraft: Mob Squad: Never Say Nether',
#  'The Case of the Curious Scouts',
#  'Firefly',
#  'Hollywood vs. the Galaxy',
#  'A to Z Mysteries Super Edition 2: Mayflower Treasure Hunt',
#  'Map of Flames',
#  'The Jungle Book',
#  'Mystery of the Midnight Rider',
#  'The Smoke Thieves',
#  'The Haunting on Heliotrope Lane',
#  'The Stolen Show',
#  'Minecraft: The Crash',
#  'Scorpia Rising',
#  'Song of the Poison Dragon',
#  "Three Tales of My Father's Dragon",
#  'Treasure Hunters',
#  'Star Wars: The Last Jedi',
#  'Captain Underpants and the Perilous Plot of Professor Poopypants',
#  'Captain Underpants and the Invasion of the Incredibly Naughty Cafeteria Ladies from Outer Space',
#  'Famous Mistakes',
#  'Minecraft: The Lost Journals',
#  "The Witch's Boy",
#  'Whatever After Collection, Books 1-3',
#  'The Hive Queen',
#  'Mac Saves the World',
#  'My Parents Cancelled My Birthday',
#  'Nightfall',
#  'The Curse of the Ancient Emerald',
#  'The Last Kids on Earth and the Skeleton Road',
#  'Doctor Who: Thirteen Doctors 13 Stories',
#  "The Gray Hunter's Revenge",
#  'Magisterium: The Iron Trial',
#  "Mr. Lemoncello's Great Library Race",
#  'The Fourth Closet',
#  'The Magic School Bus Inside the Human Body',
#  'Power of the Fire Dragon',
#  'School for Crooks',
#  'Magisterium: The Golden Tower',
#  'The Troll',
#  'Lockwood & Co.',
#  'Never Fade',
#  '100 Cupboards',
#  'Ben Braver and the Vortex of Doom',
#  'The Magic Misfits: The Second Story',
#  'The Election Day Dilemma',
#  "Tiger's Curse",
#  'Just William - More William',
#  'Public Enemy Number Two',
#  'Mercy Watson #3',
#  'A to Z Mysteries: The Zombie Zone',
#  'Afternoon on the Amazon',
#  'Troll Mountain',
#  'The Jungle Book',
#  'The Magic Misfits: The Fourth Suit',
#  "Princess Ellie's Holiday Adventure",
#  'Wizard for Hire',
#  'Hour of the Olympics',
#  'Princess Ellie to the Rescue',
#  "Father Christmas's Fake Beard",
#  'One Stormy Day',
#  'The Jungle Book',
#  'LEGO Ninjago: Brick Adventures #1: Brother/Sister Squad',
#  'Infinity Ring, Book 3: The Trap Door',
#  'The Emperor of Nihon-Ja',
#  'The Comic Book Mystery',
#  "Nick and Tesla's High-Voltage Danger Lab",
#  'The Penderwicks on Gardam Street',
#  'The Midnight Mystery',
#  'The Missing Prince',
#  'The Sound of Danger',
#  'Mac Undercover',
#  'Adventures from the Land of Stories Boxed Set',
#  'El Ickabog (Spanish Edition)',
#  'The Star of Kazan',
#  'The Sea Turtle Mystery',
#  'Black Beauty',
#  'Shoe Wars',
#  'Fablehaven, Book 2',
#  'Good Dog',
#  'Winter Turning',
#  'The 39 Clues, Book 7',
#  'Trust No One',
#  'The Quest for the Artifacts',
#  'The 117-Storey Treehouse',
#  'The Mighty Odds',
#  'Hansel and Gretel',
#  'The 39 Clues: Flashpoint',
#  'Earthquake',
#  'Stolen Identity',
#  'Dr. Fell and the Playground of Doom',
#  'The 39 Clues',
#  'Rostig!',
#  'Il principe e il leone',
#  'Child I',
#  'Die neue Zeit',
#  'The Tzar’s Curious Runaways',
#  'The Dead World of Lanthorne Ghules',
#  'PIN-0-TXO vol tenir superforça',
#  'Zack Galaxy: persecución total',
#  'Zack Galaxy: una aventura intergaláctica',
#  'Relatos fantásticos',
#  'El niño que siempre decía sí',
#  '¡Menuda cabeza!',
#  'Quin cap!',
#  'El Bloque',
#  'Eine Freundschaft aus Wind und Magie',
#  'Alarm in der Delfin-Lagune',
#  'Tschakka! - Huhn voraus',
#  "George's Cosmic Treasure Hunt",
#  'Magisterium: The Copper Gauntlet',
#  'The Penderwicks at Point Mouette',
#  'Stormspeaker',
#  'Evie and the Animals',
#  'Black Beauty',
#  'The Count of Monte Cristo',
#  'The Boy Who Dreamed of Dragons',
#  'The Guggenheim Mystery',
#  'George and the Blue Moon',
#  'Escaping Peril',
#  'The Case of the Deadly Ha-Ha Game',
#  'Rise and Fall',
#  'The Great Paper Caper',
#  'Broken: The Vampires, the Magic Stones, and the Cursed Child',
#  'Caterflies and Ice',
#  'George and the Unbreakable Code',
#  'George and the Ship of Time',
#  'Shadows at Predator Reef',
#  "Charlie Cook's Favourite Book",
#  'Klawde: Evil Alien Warlord Cat, Book 1',
#  'Ringo & the Yogi',
#  'The Miraculous Journey of Edward Tulane',
#  'Roar of the Thunder Dragon',
#  'The Mercy Watson Collection',
#  'Narwhal on a Sunny Night',
#  "The Jungle Book (BBC Children's Classics)",
#  'The Drowned Vault',
#  'The Green Ember',
#  'The Burning Tide',
#  'My Side of the Mountain',
#  'Magisterium: The Silver Mask',
#  'Evie in the Jungle',
#  'Battle for Loot Lake: An Unofficial Fortnite Adventure Novel',
#  'Midnight for Charlie Bone',
#  'Winnie-the-Pooh',
#  'Midnight on the Moon',
#  "Erak's Ransom",
#  ...]

# %%
audible_dataset[audible_dataset['price']=='Free']
# Out:
#                                             name  \
# 983                             Ringo & the Yogi
# 1414                        The Velveteen Rabbit
# 1513       Billi Aur Moosarani [Cat and Musrani]
# 2932           Pariyon Ki Kahaniya [Fairy Tales]
# 4547         101 Best Indian Fables for Children
# ...                                          ...
# 80021                           FREE: The Undead
# 81198                      Supporters. Le Pilote
# 82644                         Boots Belts Berets
# 86771                          Canada Is Awesome
# 86927  Osez l'aventure avec Mike Horn. Le pilote
#
#                                      author  \
# 983                     Writtenby:PrasunRoy
# 1414              Writtenby:MargeryWilliams
# 1513                      Writtenby:Shivani
# 2932                   Writtenby:JacobGrimm
# 4547                   Writtenby:StutiGupta
# ...                                     ...
# 80021                   Writtenby:RRHaywood
# 81198  Writtenby:PierreNiboyet,AudreyPoiret
# 82644             Writtenby:TanushreePodder
# 86771                Writtenby:NeilPasricha
# 86927      Writtenby:MikeHorn,CharlesAudier
#
#                                 narrator               time releasedate  \
# 983            Narratedby:SiddhantaPinto  5 hrs and 18 mins    19-11-19
# 1414          Narratedby:RichardArmitage            24 mins    14-08-20
# 1513              Narratedby:SarahHashmi            26 mins    14-10-21
# 2932          Narratedby:AnuradhaChauhan  2 hrs and 15 mins    08-12-21
# 4547      Narratedby:SunandhaRaghunathan  2 hrs and 26 mins    03-12-19
# ...                                  ...                ...         ...
# 80021               Narratedby:DanMorgan    1 hr and 3 mins    24-02-15
# 81198          Narratedby:BorisRehlinger            24 mins    29-10-20
# 82644    Narratedby:RannvijaySinghSingha  6 hrs and 59 mins    27-08-19
# 86771            Narratedby:NeilPasricha            34 mins    09-10-18
# 86927  Narratedby:MikeHorn,CharlesAudier            24 mins    11-01-22
#
#       language                          stars price
# 983    English      4 out of 5 stars4 ratings  Free
# 1414   English   4.5 out of 5 stars91 ratings  Free
# 1513     Hindi                  Not rated yet  Free
# 2932     Hindi                  Not rated yet  Free
# 4547   English      4 out of 5 stars3 ratings  Free
# ...        ...                            ...   ...
# 80021  English      4 out of 5 stars8 ratings  Free
# 81198   french                  Not rated yet  Free
# 82644  English  4.5 out of 5 stars158 ratings  Free
# 86771  English   4.5 out of 5 stars29 ratings  Free
# 86927   french                  Not rated yet  Free
#
# [338 rows x 8 columns]
